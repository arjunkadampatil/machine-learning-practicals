# %% [markdown]
# # Practical 07: Geopolitical Conflict Classification
#
# ## Objective
# To develop a machine learning classification model that predicts the geopolitical relationship between countries using multi-dimensional features such as military strength, economy, ideology, and sentiment.

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.utils import to_categorical

# %% [markdown]
# ## Load Dataset

# %%
df = pd.read_csv("geopolitical_dataset.csv")
df.head()
# Out:
#    military_power_ratio  troop_movement  nuclear_capability  nuclear_warheads  \
# 0              1.061810              46                   0                20
# 1              1.926071              11                   0               157
# 2              1.597991              61                   0               268
# 3              1.397988              79                   0               161
# 4              0.734028              87                   1               259
#
#    gdp_ratio  sanctions_intensity  trade_dependency  ideology_distance  \
# 0   1.514162                    7          0.949273           0.844864
# 1   1.915973                    7          0.879601           0.359676
# 2   0.903452                    9          0.907042           0.687234
# 3   1.213110                    6          0.991533           0.312834
# 4   1.451510                    4          0.208315           0.060906
#
#    political_stability  historical_conflict  border_distance  news_sentiment  \
# 0             0.934033                    5       793.537402       -0.740587
# 1             0.766351                    6        85.599553       -0.092492
# 2             0.657950                    0       183.457885        0.013860
# 3             0.823896                    0       758.403673        0.374780
# 4             0.647520                    4        21.986522        0.266567
#
#    nationalism_index  leader_aggression  target
# 0           0.084002           0.274637       1
# 1           0.681526           0.273081       1
# 2           0.680110           0.302622       1
# 3           0.669080           0.612313       1
# 4           0.942334           0.438333       1

# %% [markdown]
# ## Data Preprocessing

# %%
print(df.isnull().sum())

X = df.drop('target', axis=1)
y = df['target']

y = to_categorical(y)

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
# Out:
# military_power_ratio    0
# troop_movement          0
# nuclear_capability      0
# nuclear_warheads        0
# gdp_ratio               0
# sanctions_intensity     0
# trade_dependency        0
# ideology_distance       0
# political_stability     0
# historical_conflict     0
# border_distance         0
# news_sentiment          0
# nationalism_index       0
# leader_aggression       0
# target                  0
# dtype: int64

# %% [markdown]
# ## Train-Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42
)

# %% [markdown]
# ## Build Neural Network Model

# %%
model = Sequential([
    Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    Dropout(0.3),
    Dense(32, activation='relu'),
    Dropout(0.3),
    Dense(y.shape[1], activation='softmax')
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# ## Compile Model

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# ## Train Model

# %%
history = model.fit(
    X_train, y_train,
    epochs=30,
    batch_size=32,
    validation_split=0.2
)
# Out:
# Epoch 1/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.1531 - loss: 1.7462 - val_accuracy: 0.3313 - val_loss: 1.4739
# Epoch 2/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3297 - loss: 1.4719 - val_accuracy: 0.4375 - val_loss: 1.2903
# Epoch 3/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4531 - loss: 1.3056 - val_accuracy: 0.5125 - val_loss: 1.1773
# Epoch 4/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4594 - loss: 1.2195 - val_accuracy: 0.5688 - val_loss: 1.1015
# Epoch 5/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4938 - loss: 1.1812 - val_accuracy: 0.6250 - val_loss: 1.0462
# Epoch 6/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5203 - loss: 1.1132 - val_accuracy: 0.6438 - val_loss: 0.9916
# Epoch 7/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5516 - loss: 1.0463 - val_accuracy: 0.7125 - val_loss: 0.9290
# Epoch 8/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5750 - loss: 1.0183 - val_accuracy: 0.7563 - val_loss: 0.8661
# Epoch 9/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6250 - loss: 0.9584 - val_accuracy: 0.7750 - val_loss: 0.8064
# Epoch 10/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6609 - loss: 0.8773 - val_accuracy: 0.7750 - val_loss: 0.7384
# Epoch 11/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6969 - loss: 0.8103 - val_accuracy: 0.8000 - val_loss: 0.6784
# Epoch 12/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7203 - loss: 0.7416 - val_accuracy: 0.8188 - val_loss: 0.6225
# Epoch 13/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7156 - loss: 0.7325 - val_accuracy: 0.8313 - val_loss: 0.5784
# Epoch 14/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7578 - loss: 0.6822 - val_accuracy: 0.8438 - val_loss: 0.5434
# Epoch 15/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7625 - loss: 0.6493 - val_accuracy: 0.8500 - val_loss: 0.5128
# Epoch 16/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7703 - loss: 0.6161 - val_accuracy: 0.8625 - val_loss: 0.4901
# Epoch 17/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7641 - loss: 0.6024 - val_accuracy: 0.8687 - val_loss: 0.4663
# Epoch 18/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7672 - loss: 0.5711 - val_accuracy: 0.8813 - val_loss: 0.4422
# Epoch 19/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8016 - loss: 0.5304 - val_accuracy: 0.8875 - val_loss: 0.4223
# Epoch 20/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7875 - loss: 0.5272 - val_accuracy: 0.8875 - val_loss: 0.3980
# Epoch 21/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7984 - loss: 0.5170 - val_accuracy: 0.8625 - val_loss: 0.3803
# Epoch 22/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8297 - loss: 0.4777 - val_accuracy: 0.8813 - val_loss: 0.3645
# Epoch 23/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8078 - loss: 0.4826 - val_accuracy: 0.8875 - val_loss: 0.3541
# Epoch 24/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8141 - loss: 0.4700 - val_accuracy: 0.8938 - val_loss: 0.3418
# Epoch 25/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8406 - loss: 0.4310 - val_accuracy: 0.8938 - val_loss: 0.3332
# Epoch 26/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8250 - loss: 0.4463 - val_accuracy: 0.9062 - val_loss: 0.3194
# Epoch 27/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8109 - loss: 0.4545 - val_accuracy: 0.8875 - val_loss: 0.3095
# Epoch 28/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8359 - loss: 0.4300 - val_accuracy: 0.9062 - val_loss: 0.3024
# Epoch 29/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8531 - loss: 0.3771 - val_accuracy: 0.9000 - val_loss: 0.2918
# Epoch 30/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8484 - loss: 0.3926 - val_accuracy: 0.9000 - val_loss: 0.2894

# %% [markdown]
# ## Accuracy Visualization

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

plt.title("Model Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(['Train','Validation'])
plt.show()

# %% [markdown]
# ## Model Evaluation

# %%
test_loss, test_acc = model.evaluate(X_test, y_test)
print("Test Accuracy:", test_acc)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9200 - loss: 0.2448
# Test Accuracy: 0.9200000166893005

# %% [markdown]
# ## Classification Report

# %%
y_pred = model.predict(X_test)

y_pred_classes = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test, axis=1)

print(classification_report(y_true, y_pred_classes))
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      0.50      0.67         6
#            1       0.95      0.99      0.97       100
#            2       0.87      0.96      0.91        69
#            3       0.94      0.64      0.76        25
#
#     accuracy                           0.92       200
#    macro avg       0.94      0.77      0.83       200
# weighted avg       0.92      0.92      0.91       200

# %% [markdown]
# ## Confusion Matrix

# %%
cm = confusion_matrix(y_true, y_pred_classes)

sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# ## Feature Correlation Analysis

# %%
corr = df.corr()

plt.figure(figsize=(10,8))
sns.heatmap(corr, cmap='coolwarm')
plt.title("Feature Correlation")
plt.show()

# %% [markdown]
# ## Conclusion
#
# A Neural Network model was successfully developed to classify geopolitical relationships. The model achieved good accuracy and identified key feature relationships influencing global conflict prediction.
